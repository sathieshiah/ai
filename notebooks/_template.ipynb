# %% [markdown]
# # <title>
#
# **What question does this notebook answer?** One or two sentences. If you cannot
# write this, you are not ready to start coding.
#
# | | |
# |---|---|
# | Date | YYYY-MM-DD |
# | Model(s) | `org/model-id` @ revision |
# | dtype | float32 |
# | Seed | 0 |
#
# Kernel must read **`Python (research ARM64)`** (top right).

# %%
import research                    # first - pins HF cache to D:/research/models
from research import models, paths

import matplotlib.pyplot as plt
import pandas as pd
import torch

SEED = 0
torch.manual_seed(SEED)

# %% [markdown]
# ## Setup

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Findings
#
# Write the answer here, in prose. Then copy it into `docs/` — a result that
# lives only in this notebook is not finished.
#
# -
